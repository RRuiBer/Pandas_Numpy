# %% [markdown]
# ## Condiciones

# %% [markdown]
# ### Entorno de trabajo
# Importamos pandas y realizamos una lectura de un archivo csv usando $pd.read\_ csv('/dirección/del/archivo.csv')$

# %%
import pandas as pd

# %%
data = pd.read_csv('data/bestsellers-with-categories.csv')
data.loc[:5]
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
# 5       George R. R. Martin          4.4    12643     11  2011      Fiction

# %% [markdown]
# ### Explorar el data set
# Aplicar condiciones al data frame genera datos booleanos. Podemos aplicar condiciones a las filas o a las columnas.

# %%
data.loc[:10]['Year'] > 2012
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4      True
# 5     False
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# Name: Year, dtype: bool

# %% [markdown]
# Podemos reescribir la variable o crear una nueva en la que se apliquen las condiciones especificadas:

# %%
data[data['Year'] > 2013]
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# 6    A Game of Thrones / A Clash of Kings / A Storm...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# ...

# %% [markdown]
# Podemos filtrar datos de nuestro interés ocupando las condiciones. Por ejemplo: libros de ficción publicados después del 2015.

# %%
data[(data['Genre'] == 'Fiction') & (data['Year'] > 2015)]
# Out:
#                                                   Name             Author  \
# 3                               1984 (Signet Classics)      George Orwell
# 7                       A Gentleman in Moscow: A Novel        Amor Towles
# 9                            A Man Called Ove: A Novel    Fredrik Backman
# 10                           A Man Called Ove: A Novel    Fredrik Backman
# 13                    A Wrinkle in Time (Time Quintet)  Madeleine L'Engle
# ..                                                 ...                ...
# 529  What Should Danny Do? (The Power to Choose Ser...          Adir Levy
# 534                            Where the Crawdads Sing        Delia Owens
# 543                                             Wonder      R. J. Palacio
# 544                                             Wonder      R. J. Palacio
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)        Jeff Kinney
#
#      User Rating  Reviews  Price  Year    Genre
# ...

# %% [markdown]
# En pandas, el símbolo ~ genera la negación de la condición.

# %%
data[(data['Genre'] == 'Fiction') & ~(data['Year'] > 2015)]
# Out:
#                                                   Name               Author  \
# 1                                    11/22/63: A Novel         Stephen King
# 5        A Dance with Dragons (A Song of Ice and Fire)  George R. R. Martin
# 6    A Game of Thrones / A Clash of Kings / A Storm...  George R. R. Martin
# 20                         All the Light We Cannot See        Anthony Doerr
# 21                         All the Light We Cannot See        Anthony Doerr
# ..                                                 ...                  ...
# 535                          Where the Wild Things Are       Maurice Sendak
# 538  Winter of the World: Book Two of the Century T...          Ken Follett
# 540                                             Wonder        R. J. Palacio
# 541                                             Wonder        R. J. Palacio
# 542                                             Wonder        R. J. Palacio
#
#      User Rating  Reviews  Price  Year    Genre
# ...
