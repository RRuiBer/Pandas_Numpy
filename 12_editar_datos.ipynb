# %% [markdown]
# ## Agregar y eliminar datos

# %%
import pandas as pd
import numpy as np

# %%
data_books = pd.read_csv('data/bestsellers-with-categories.csv')

# %%
data_books.loc[:5]
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
# 5       George R. R. Martin          4.4    12643     11  2011      Fiction

# %% [markdown]
# ### Eliminar columnas

# %% [markdown]
# #### drop()
# Para eliminar columnas de un data frame, si $data$ es una variable donde se ha cargado un archivo csv con $pd.read\_ csv()$, usamos $drop()$ como se muestra a continuación:
# $$data.drop('columna',\ axis=i)\hspace{0.3 cm}i=0,\ 1.$$
# En el parámetro $axis$, $0$ corresponde a las filas y $1$ corresponde a las columnas y en el parámetro $'columna'$ podemos poner una lista con más de una columna: $['columna1,\ 'columna2']$.

# %%
data_books.drop(['User Rating','Price'],axis=1).loc[:5] # se usó la función loc para mostrar pocas filas
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
#
#                      Author  Reviews  Year        Genre
# 0                  JJ Smith    17350  2016  Non Fiction
# 1              Stephen King     2052  2011      Fiction
# 2        Jordan B. Peterson    18979  2018  Non Fiction
# 3             George Orwell    21424  2017      Fiction
# 4  National Geographic Kids     7665  2019  Non Fiction
# 5       George R. R. Martin    12643  2011      Fiction

# %% [markdown]
# Si se vuelve a invocar el data frame las filas borradas anteriormente volverás a ser mostradas.

# %%
data_books.loc[:5]
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
# 5       George R. R. Martin          4.4    12643     11  2011      Fiction

# %% [markdown]
# Para eliminar las columnas de manera permanente se puede agregar la sentencia $inplace$ a los parámetros de $drop()$
# $$data.drop('columna',\ axis=i,\ inplace=True)$$

# %%
data_books.drop('Year',axis=1,inplace=True)

# %%
data_books.loc[:5]
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
#
#                      Author  User Rating  Reviews  Price        Genre
# 0                  JJ Smith          4.7    17350      8  Non Fiction
# 1              Stephen King          4.6     2052     22      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  Non Fiction
# 3             George Orwell          4.7    21424      6      Fiction
# 4  National Geographic Kids          4.8     7665     12  Non Fiction
# 5       George R. R. Martin          4.4    12643     11      Fiction

# %% [markdown]
# Otra forma de eliminar columnas permanentemente es reescribir el data frame usando drop().
# $$data = data.drop('columna',\ axis=i)$$

# %%
data_books = data_books.drop('User Rating',axis=1)

# %%
data_books.loc[:5]
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
#
#                      Author  Reviews  Price        Genre
# 0                  JJ Smith    17350      8  Non Fiction
# 1              Stephen King     2052     22      Fiction
# 2        Jordan B. Peterson    18979     15  Non Fiction
# 3             George Orwell    21424      6      Fiction
# 4  National Geographic Kids     7665     12  Non Fiction
# 5       George R. R. Martin    12643     11      Fiction

# %% [markdown]
# Podemos eliminar columnas con funciones nativas de python que no son propias de pandas (no recomendado):
# $$del\hspace{0.2 cm} data['columna'].$$

# %%
del data_books['Price']

# %%
data_books.loc[:5]
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
#
#                      Author  Reviews        Genre
# 0                  JJ Smith    17350  Non Fiction
# 1              Stephen King     2052      Fiction
# 2        Jordan B. Peterson    18979  Non Fiction
# 3             George Orwell    21424      Fiction
# 4  National Geographic Kids     7665  Non Fiction
# 5       George R. R. Martin    12643      Fiction

# %% [markdown]
# ### Eliminar filas

# %% [markdown]
# drop() también permite borrar columnas usando $axis=0$:
# $$data.drop(i,\ axis=0)\hspace{0.3 cm}i\text{ es el número de fila}.$$
# También podemos poner una lista de enteros $[i,\ j,\ k,\ ...]$ o un rango $range()$ en el parámetro donde van las filas para borrar varias filas.

# %%
data_books.drop([0,2],axis=0).loc[:5]
# Out:
#                                                 Name  \
# 1                                  11/22/63: A Novel
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
#
#                      Author  Reviews        Genre
# 1              Stephen King     2052      Fiction
# 3             George Orwell    21424      Fiction
# 4  National Geographic Kids     7665  Non Fiction
# 5       George R. R. Martin    12643      Fiction

# %% [markdown]
# Como en el caso anterior, usar solamente drop() no elimina permanentemente las filas.

# %% [markdown]
# ### Añadir columnas

# %% [markdown]
# Para añadir columnas:
# $$data['column\_ name'] = \text{asignación de contenido}$$

# %%
data_books['Numeración'] = np.nan
data_books.loc[:5]
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
# 5      A Dance with Dragons (A Song of Ice and Fire)
#
#                      Author  Reviews        Genre  Numeración
# 0                  JJ Smith    17350  Non Fiction         NaN
# 1              Stephen King     2052      Fiction         NaN
# 2        Jordan B. Peterson    18979  Non Fiction         NaN
# 3             George Orwell    21424      Fiction         NaN
# 4  National Geographic Kids     7665  Non Fiction         NaN
# 5       George R. R. Martin    12643      Fiction         NaN

# %% [markdown]
# Podemos obtener el número de filas con $shape[0]$

# %%
data_books.shape[0]
# Out:
# 550

# %%
data_books['Numeración'] = np.arange(0,data_books.shape[0])
data_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  Reviews        Genre  Numeración
# 0                    JJ Smith    17350  Non Fiction           0
# 1                Stephen King     2052      Fiction           1
# 2          Jordan B. Peterson    18979  Non Fiction           2
# 3               George Orwell    21424      Fiction           3
# 4    National Geographic Kids     7665  Non Fiction           4
# ..                        ...      ...          ...         ...
# 545               Jeff Kinney     9413      Fiction         545
# 546               Jen Sincero    14331  Non Fiction         546
# 547               Jen Sincero    14331  Non Fiction         547
# 548               Jen Sincero    14331  Non Fiction         548
# 549               Jen Sincero    14331  Non Fiction         549
#
# [550 rows x 5 columns]

# %% [markdown]
# ### Agregar filas

# %% [markdown]
# Podemos crear un diccionario con los datos que queremos agregar:

# %%
otros_libros = {'Name':'Libro que no existe','Author':'Ricardo R','Reviews':0,'Genre':'Fiction','Numeración':1200}

# %% [markdown]
# Para agregar las filas concatenamos los dos data sets:
# $$pd.concat([data_1,\ pd.DataFrame([\text{diccionario con los nuevos datos}])],\ ignore\_ index=True)$$

# %%
data_books = pd.concat([data_books,pd.DataFrame([otros_libros])],ignore_index=True)
data_books
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
# 550                                Libro que no existe
#
#                        Author  Reviews        Genre  Numeración
# 0                    JJ Smith    17350  Non Fiction           0
# 1                Stephen King     2052      Fiction           1
# 2          Jordan B. Peterson    18979  Non Fiction           2
# 3               George Orwell    21424      Fiction           3
# 4    National Geographic Kids     7665  Non Fiction           4
# ..                        ...      ...          ...         ...
# 546               Jen Sincero    14331  Non Fiction         546
# 547               Jen Sincero    14331  Non Fiction         547
# 548               Jen Sincero    14331  Non Fiction         548
# 549               Jen Sincero    14331  Non Fiction         549
# 550                 Ricardo R        0      Fiction        1200
#
# [551 rows x 5 columns]
